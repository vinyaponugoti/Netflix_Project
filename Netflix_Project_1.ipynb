# %%
# Notes
# only extracting show data
# highlight num of seasons for chatbot questions

# %%
# imports
import csv
import pandas as pd
import os
import datetime
import pymongo
import pprint

# %%
# loading in relevant CSVs (show data only)
shows = pd.read_csv('Best Shows Netflix.csv')
shows
# Out:
#      index                       TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 0        0                Breaking Bad          2008    9.5          1727694
# 1        1  Avatar: The Last Airbender          2005    9.3           297336
# 2        2                  Our Planet          2019    9.3            41386
# 3        3                Kota Factory          2019    9.3            66985
# 4        4              The Last Dance          2020    9.1           108321
# ..     ...                         ...           ...    ...              ...
# 241    241                 Evil Genius          2018    7.5            27516
# 242    242              13 Reasons Why          2017    7.5           282373
# 243    243                       Lupin          2021    7.5           100575
# 244    244          All of Us Are Dead          2022    7.5            41393
# 245    245     I Am Not Okay with This          2020    7.5            56459
#
# ...

# %%
# only using SCORE column to determine show ranking, so don't need NUMBER_OF_VOTES column
shows.drop('NUMBER_OF_VOTES', axis = 1)
# Out:
#      index                       TITLE  RELEASE_YEAR  SCORE  DURATION  \
# 0        0                Breaking Bad          2008    9.5        48
# 1        1  Avatar: The Last Airbender          2005    9.3        24
# 2        2                  Our Planet          2019    9.3        50
# 3        3                Kota Factory          2019    9.3        42
# 4        4              The Last Dance          2020    9.1        50
# ..     ...                         ...           ...    ...       ...
# 241    241                 Evil Genius          2018    7.5        48
# 242    242              13 Reasons Why          2017    7.5        58
# 243    243                       Lupin          2021    7.5        46
# 244    244          All of Us Are Dead          2022    7.5        61
# 245    245     I Am Not Okay with This          2020    7.5        21
#
#      NUMBER_OF_SEASONS   MAIN_GENRE MAIN_PRODUCTION
# 0                    5        drama              US
# ...

# %%
shows_year = pd.read_csv('Best Show by Year Netflix.csv')
shows_year
# Out:
#     index                         TITLE  RELEASE_YEAR  SCORE  \
# 0       0  Monty Python's Flying Circus          1969    8.8
# 1       1                  Knight Rider          1982    6.9
# 2       2                      Seinfeld          1989    8.9
# 3       3    Star Trek: Deep Space Nine          1993    8.1
# 4       4       Neon Genesis Evangelion          1995    8.5
# 5       5                 Stargate SG-1          1997    8.4
# 6       6                  Cowboy Bebop          1998    8.9
# 7       7                     One Piece          1999    8.8
# 8       8                 Gilmore Girls          2000    8.2
# 9       9             Trailer Park Boys          2001    8.6
# 10     10                        Naruto          2002    8.4
# 11     11              Chappelle's Show          2003    8.8
# 12     12                      The 4400          2004    7.3
# 13     13    Avatar: The Last Airbender          2005    9.3
# ...

# %%
# only using MAIN_PRODUCTION column from general df, so don't need it here 
shows_year.drop('MAIN_PRODUCTION', axis = 1)
# Out:
#     index                         TITLE  RELEASE_YEAR  SCORE  \
# 0       0  Monty Python's Flying Circus          1969    8.8
# 1       1                  Knight Rider          1982    6.9
# 2       2                      Seinfeld          1989    8.9
# 3       3    Star Trek: Deep Space Nine          1993    8.1
# 4       4       Neon Genesis Evangelion          1995    8.5
# 5       5                 Stargate SG-1          1997    8.4
# 6       6                  Cowboy Bebop          1998    8.9
# 7       7                     One Piece          1999    8.8
# 8       8                 Gilmore Girls          2000    8.2
# 9       9             Trailer Park Boys          2001    8.6
# 10     10                        Naruto          2002    8.4
# 11     11              Chappelle's Show          2003    8.8
# 12     12                      The 4400          2004    7.3
# 13     13    Avatar: The Last Airbender          2005    9.3
# ...

# %%
# connecting to MongoDB
host_name = "localhost"
port = "27017"

atlas_cluster_name = "sandbox"
atlas_default_dbname = "local"

# %%
conn_str = {
    "local" : f"mongodb://{host_name}:{port}/",
#    "atlas" : f"mongodb+srv://{atlas_user_name}:{atlas_password}@{atlas_cluster_name}.zibbf.mongodb.net/{atlas_default_dbname}"
}

client = pymongo.MongoClient(conn_str["local"])

print(f"Local Connection String: {conn_str['local']}")
# Out:
# Local Connection String: mongodb://localhost:27017/

# %%
# creating a MongoDB
db = client['shows']
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
# creating a Mongo collection
collection = db.collection.insert_many(shows.to_dict('records'))

# %%
# checking Mongo collection lists
db.list_collection_names()
# Out:
# ['collection']

# %%
# create MongoDB connection for shows by_year
host_name = "localhost"
port = "27017"

atlas_cluster_name = "sandbox"
atlas_default_dbname = "local"

# %%
conn_str = {
    "local" : f"mongodb://{host_name}:{port}/",
#    "atlas" : f"mongodb+srv://{atlas_user_name}:{atlas_password}@{atlas_cluster_name}.zibbf.mongodb.net/{atlas_default_dbname}"
}

client = pymongo.MongoClient(conn_str["local"])

print(f"Local Connection String: {conn_str['local']}")
# Out:
# Local Connection String: mongodb://localhost:27017/

# %%
# creating a MongoDB for shows_year
db2 = client['shows_year']
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'shows']

# %%
# creating a Mongo collection for shows_year
collection2 = db2.collection2.insert_many(shows.to_dict('records'))

# %%
# checking updated Mongo collection lists
db2.list_collection_names()
# Out:
# ['collection', 'collection2']

# %%
# checking all values from pandas df are in new MongoDB
pprint.pprint(collection.inserted_ids)
# Out:
# [ObjectId('6394eed7f760f3c3f2fb922c'),
#  ObjectId('6394eed7f760f3c3f2fb922d'),
#  ObjectId('6394eed7f760f3c3f2fb922e'),
#  ObjectId('6394eed7f760f3c3f2fb922f'),
#  ObjectId('6394eed7f760f3c3f2fb9230'),
#  ObjectId('6394eed7f760f3c3f2fb9231'),
#  ObjectId('6394eed7f760f3c3f2fb9232'),
#  ObjectId('6394eed7f760f3c3f2fb9233'),
#  ObjectId('6394eed7f760f3c3f2fb9234'),
#  ObjectId('6394eed7f760f3c3f2fb9235'),
#  ObjectId('6394eed7f760f3c3f2fb9236'),
#  ObjectId('6394eed7f760f3c3f2fb9237'),
#  ObjectId('6394eed7f760f3c3f2fb9238'),
#  ObjectId('6394eed7f760f3c3f2fb9239'),
#  ObjectId('6394eed7f760f3c3f2fb923a'),
#  ObjectId('6394eed7f760f3c3f2fb923b'),
#  ObjectId('6394eed7f760f3c3f2fb923c'),
#  ObjectId('6394eed7f760f3c3f2fb923d'),
#  ObjectId('6394eed7f760f3c3f2fb923e'),
#  ObjectId('6394eed7f760f3c3f2fb923f'),
#  ObjectId('6394eed7f760f3c3f2fb9240'),
#  ObjectId('6394eed7f760f3c3f2fb9241'),
#  ObjectId('6394eed7f760f3c3f2fb9242'),
#  ObjectId('6394eed7f760f3c3f2fb9243'),
# ...

# %%
# checking all values from pandas df (shows_year) are in new MongoDB
pprint.pprint(collection2.inserted_ids)
# Out:
# [ObjectId('6395010cf760f3c3f2fb9605'),
#  ObjectId('6395010cf760f3c3f2fb9606'),
#  ObjectId('6395010cf760f3c3f2fb9607'),
#  ObjectId('6395010cf760f3c3f2fb9608'),
#  ObjectId('6395010cf760f3c3f2fb9609'),
#  ObjectId('6395010cf760f3c3f2fb960a'),
#  ObjectId('6395010cf760f3c3f2fb960b'),
#  ObjectId('6395010cf760f3c3f2fb960c'),
#  ObjectId('6395010cf760f3c3f2fb960d'),
#  ObjectId('6395010cf760f3c3f2fb960e'),
#  ObjectId('6395010cf760f3c3f2fb960f'),
#  ObjectId('6395010cf760f3c3f2fb9610'),
#  ObjectId('6395010cf760f3c3f2fb9611'),
#  ObjectId('6395010cf760f3c3f2fb9612'),
#  ObjectId('6395010cf760f3c3f2fb9613'),
#  ObjectId('6395010cf760f3c3f2fb9614'),
#  ObjectId('6395010cf760f3c3f2fb9615'),
#  ObjectId('6395010cf760f3c3f2fb9616'),
#  ObjectId('6395010cf760f3c3f2fb9617'),
#  ObjectId('6395010cf760f3c3f2fb9618'),
#  ObjectId('6395010cf760f3c3f2fb9619'),
#  ObjectId('6395010cf760f3c3f2fb961a'),
#  ObjectId('6395010cf760f3c3f2fb961b'),
#  ObjectId('6395010cf760f3c3f2fb961c'),
# ...

# %%
# start chatbot

import nltk 
# import discord
nltk.download('punkt')

from nltk import word_tokenize,sent_tokenize

from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()
#read more on the steamer https://towardsdatascience.com/stemming-lemmatization-what-ba782b7c0bd8
import numpy as np 
import tflearn
import tensorflow as tf
import random
import json
import pickle
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/maniktuladhar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-9c07f838fded> in <module>
#       9 #read more on the steamer https://towardsdatascience.com/stemming-lemmatization-what-ba782b7c0bd8
#      10 import numpy as np
# ---> 11 import tflearn
#      12 import tensorflow as tf
#      13 import random
#
# ModuleNotFoundError: No module named 'tflearn'

# %% [markdown]
# **Questions:**
#
# (Lasata)
#
# *1. What are the top three highest rated shows of 2020? (general)*
#
#    1A: It's Okay Not To Be Okay, The Last Dance, The Queen's Gambit
#
# *Alternate Form of Q:*
#
#    Show me the top three highest rated shows of 2020. Show me the top 3 highest rated shows of 2020.
#
#
# *2. How many seasons did the top show of 2022 have? (by year)*
#
#    2A: 1
#
# *Alternate Form of Q:*
#
#    Show me the number of seasons the top show of 2022 had. Show me the # of seasons the top show of 2022 had.
#
#
# *3. For 2018, what shows had an episode duration of 30 minutes or less? (general)*
#
#    3A: Derry Girls, Devilman Crybaby, Everything Sucks!, Hilda, On My Block, Rascal Does Not Dream of Bunny Girl          Senpai, She-Ra and the Princesses of Power, The Dragon Prince, The Kominsky Method, Violet Evergarden
#
# *Alternate Form of Q:*
#
#    Show me the shows that had an episode duration of 30 minutes or less. Show me the shows that had an episode            duration of 30 mins or less. Show me the shows that had an episode duration of thirty minutes or less. Show me the    shows that had an episode duration of thirty mins or less.
#
# *4. For the highest rated show in 2005, what was its genre? (by year)*
#
#    4A: Sci-fi
#
# *Alternate Form of Q:*
#
#    What was the genre of the highest rated show in 2005? Show me the genre of the highest rated show in 2005.
#
#
# *5. Where was the show with the highest rating of 2021 produced? (general)*
#
#    5A: US
#
# *Alternate Form of Q:*
#
#    Show me where the highest rated show of 2021 was produced. For 2021, where was the highest rated show produced?
#
# ---
# (Vinya)
#
# *6. In 2008, what was the name of the highest rated show? (by year)*
#
#    6A: Breaking Bad
#
# *Alternate Form of Q:*
#
#    What was the name of the highest rated show in 2008? Show me    the name of the highest rated show in 2008.
#
#
# *7. What are all the shows that are rated 9.0 and higher? (general)*
#
#    7A: Breaking Bad, Avatar: The Last Airbender, Our Planet, Kota Factory, The Last Dance, Arcane, Attack on Titan,      Hunter x Hunter, DEATH NOTE
#
# *Alternate Form of Q:*
#
#    Show me the names of all the shows that are rated 9.0 and higher. Show me the names of all the shows that have a      rating of nine and higher.
#
# *8. What are all the shows made in Japan after 2000? (by year)*
#
#    8A: Naruto, DEATH NOTE, Hunter x Hunter, Attack on Titan
#
# *Alternate Form of Q:*
#
#    What are all the names of the shows that were made in Japan after 2000? Show me the names of all the shows that        were made in Japan after 2000.
#
#
# *9. What are all the shows that start with the letter W? (general)*
#
#    9A: Workin' Moms, Wild Wild Country, When They See Us, Wentworth
#
# *Alternate Form of Q:*
#
#    Show me the names of all the shows that have a title starting with the letter W. What shows have a title that start    with W?
#
#
# *10. What shows are 4 seasons long? (by year)*
#
#    10A: Monty Python's Flying Circus, Knight Rider, The 4400, Attack on Titan
#
# *Alternate Form of Q:*
#
#    Show me the names of the shows that are four seasons long. Show me the names of the shows that are 4 seasons long.    Show me the titles of the shows that are 4 seasons long.
#
# ---
# *11. What is the highest rated show made in 1994? (by year)*
#
#    11A: There is currently no data on the highest rated show made in 1994.

# %%
# for intents.json file
# change patterns to questions
# change responses to answers
